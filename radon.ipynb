# %%
from modules_no_st import *
import numpy as np
from skimage.transform import radon
import cv2 as cv
import matplotlib.pyplot as plt
from skimage import color

# %%
drumhead = cv.imread("drumhead.jpg")
drum_gray = color.rgb2gray(drumhead)
plt.imshow(drum_gray)

# %%
sinogram = radon(drum_gray, theta=np.arange(0, 180, .1))
plt.imshow(sinogram,)
# Out:
# c:\Users\ernst\sample_project_1\env\lib\site-packages\skimage\transform\radon_transform.py:74: UserWarning: Radon transform: image must be zero outside the reconstruction circle
#   warn(
