# %%
import numpy as numpy
import cv2 as cv
import matplotlib.pyplot as plt
from skimage import color
from skimage.transform import rescale

drum = cv.imread("skin9b.tif")
drum_gray = color.rgb2gray(drum)
drum_small = rescale(drum_gray, 0.3)
plt.imshow(drum_small, cmap='gray');

# %%
from modules_no_st import *
coh, ang = coh_ang_calc(drum_small, epsilon=0.1, sigma_inner=3)
num_bins = 500
histogram_hopefully = weightedHistogram(coh, ang, num_bins)
# plt.imshow(cohang[:, :, 1])
plt.plot(np.arange(num_bins), histogram_hopefully);

# %%
plt.imshow(coh);

# %%
plt.imshow(drum_small, cmap='gray');

# %%
plt.imshow(orient_hsv(drum_small, coh, ang, mode='angle'));
